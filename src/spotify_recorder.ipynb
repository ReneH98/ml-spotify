# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
client_id = '342693a5bc7240649bb8cb8a17f81e0b'
client_secret = '17d4bd23b0d24287af971ec919e65d19'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(playlist_id):
    ids = []
    playlist = sp.playlist_items(playlist_id)
    
    for track_item in playlist['items']:
        ids.append(track_item['track']['id'])
        
    return ids

track_ids = getTrackIDs('37i9dQZF1DX4jP4eebSWR9')

sp.audio_features(tracks=track_ids)
# Out:
# [{'danceability': 0.658,
#   'energy': 0.604,
#   'key': 2,
#   'loudness': -5.544,
#   'mode': 0,
#   'speechiness': 0.114,
#   'acousticness': 0.121,
#   'instrumentalness': 0,
#   'liveness': 0.0764,
#   'valence': 0.27,
#   'tempo': 159.884,
#   'type': 'audio_features',
#   'id': '5Md6tmV3BU9vAHHlK5DIm9',
#   'uri': 'spotify:track:5Md6tmV3BU9vAHHlK5DIm9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Md6tmV3BU9vAHHlK5DIm9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Md6tmV3BU9vAHHlK5DIm9',
#   'duration_ms': 165587,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.805,
#   'key': 11,
#   'loudness': -5.394,
#   'mode': 0,
#   'speechiness': 0.125,
#   'acousticness': 0.0527,
#   'instrumentalness': 0,
#   'liveness': 0.192,
#   'valence': 0.873,
#   'tempo': 117.987,
#   'type': 'audio_features',
#   'id': '4wGWB56toxihHUdbnRTMb1',
#   'uri': 'spotify:track:4wGWB56toxihHUdbnRTMb1',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wGWB56toxihHUdbnRTMb1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wGWB56toxihHUdbnRTMb1',
#   'duration_ms': 216771,
#   'time_signature': 4},
#  {'danceability': 0.787,
#   'energy': 0.828,
#   'key': 11,
#   'loudness': -3.579,
#   'mode': 0,
#   'speechiness': 0.0297,
#   'acousticness': 0.106,
#   'instrumentalness': 0.000605,
#   'liveness': 0.105,
#   'valence': 0.544,
#   'tempo': 119.953,
#   'type': 'audio_features',
#   'id': '3tzR2HUk6FAGaXzkrXZpQj',
#   'uri': 'spotify:track:3tzR2HUk6FAGaXzkrXZpQj',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tzR2HUk6FAGaXzkrXZpQj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tzR2HUk6FAGaXzkrXZpQj',
#   'duration_ms': 182700,
#   'time_signature': 4},
#  {'danceability': 0.762,
#   'energy': 0.766,
#   'key': 7,
#   'loudness': -3.955,
#   'mode': 1,
#   'speechiness': 0.0343,
#   'acousticness': 0.00776,
#   'instrumentalness': 6.98e-05,
#   'liveness': 0.128,
#   'valence': 0.442,
#   'tempo': 130.001,
#   'type': 'audio_features',
#   'id': '5fwSHlTEWpluwOM0Sxnh5k',
#   'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#   'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#   'duration_ms': 287120,
#   'time_signature': 4},
#  {'danceability': 0.934,
#   'energy': 0.427,
#   'key': 7,
#   'loudness': -5.596,
#   'mode': 0,
#   'speechiness': 0.089,
#   'acousticness': 0.0689,
#   'instrumentalness': 1.53e-06,
#   'liveness': 0.082,
#   'valence': 0.609,
#   'tempo': 99.978,
#   'type': 'audio_features',
#   'id': '3sZOiHgkXpDcilUBtHSixK',
#   'uri': 'spotify:track:3sZOiHgkXpDcilUBtHSixK',
#   'track_href': 'https://api.spotify.com/v1/tracks/3sZOiHgkXpDcilUBtHSixK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3sZOiHgkXpDcilUBtHSixK',
#   'duration_ms': 140839,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.636,
#   'key': 6,
#   'loudness': -8.117,
#   'mode': 0,
#   'speechiness': 0.103,
#   'acousticness': 0.515,
#   'instrumentalness': 0.000411,
#   'liveness': 0.172,
#   'valence': 0.262,
#   'tempo': 120.966,
#   'type': 'audio_features',
#   'id': '3uUuGVFu1V7jTQL60S1r8z',
#   'uri': 'spotify:track:3uUuGVFu1V7jTQL60S1r8z',
#   'track_href': 'https://api.spotify.com/v1/tracks/3uUuGVFu1V7jTQL60S1r8z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3uUuGVFu1V7jTQL60S1r8z',
#   'duration_ms': 148197,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.781,
#   'key': 7,
#   'loudness': -5.578,
#   'mode': 0,
#   'speechiness': 0.0452,
#   'acousticness': 0.0185,
#   'instrumentalness': 3.12e-05,
#   'liveness': 0.295,
#   'valence': 0.456,
#   'tempo': 124.04,
#   'type': 'audio_features',
#   'id': '4xMbBESczlHPUO8QeYi56p',
#   'uri': 'spotify:track:4xMbBESczlHPUO8QeYi56p',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xMbBESczlHPUO8QeYi56p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xMbBESczlHPUO8QeYi56p',
#   'duration_ms': 148960,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.792,
#   'key': 10,
#   'loudness': -4.021,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.051,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.507,
#   'tempo': 122.062,
#   'type': 'audio_features',
#   'id': '3eJH2nAjvNXdmPfBkALiPZ',
#   'uri': 'spotify:track:3eJH2nAjvNXdmPfBkALiPZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3eJH2nAjvNXdmPfBkALiPZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3eJH2nAjvNXdmPfBkALiPZ',
#   'duration_ms': 139672,
#   'time_signature': 4},
#  {'danceability': 0.534,
#   'energy': 0.725,
#   'key': 1,
#   'loudness': -3.906,
#   'mode': 1,
#   'speechiness': 0.046,
#   'acousticness': 0.091,
#   'instrumentalness': 0,
#   'liveness': 0.0264,
#   'valence': 0.55,
#   'tempo': 88.098,
#   'type': 'audio_features',
#   'id': '3Kkjo3cT83cw09VJyrLNwX',
#   'uri': 'spotify:track:3Kkjo3cT83cw09VJyrLNwX',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Kkjo3cT83cw09VJyrLNwX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Kkjo3cT83cw09VJyrLNwX',
#   'duration_ms': 225149,
#   'time_signature': 4},
#  {'danceability': 0.788,
#   'energy': 0.859,
#   'key': 2,
#   'loudness': -2.724,
#   'mode': 1,
#   'speechiness': 0.0856,
#   'acousticness': 0.281,
#   'instrumentalness': 0,
#   'liveness': 0.0424,
#   'valence': 0.822,
#   'tempo': 141.02,
#   'type': 'audio_features',
#   'id': '75MNhvTCCKsST3YqqUiU9r',
#   'uri': 'spotify:track:75MNhvTCCKsST3YqqUiU9r',
#   'track_href': 'https://api.spotify.com/v1/tracks/75MNhvTCCKsST3YqqUiU9r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75MNhvTCCKsST3YqqUiU9r',
#   'duration_ms': 207853,
#   'time_signature': 4},
#  {'danceability': 0.854,
#   'energy': 0.806,
#   'key': 11,
#   'loudness': -8.262,
#   'mode': 0,
#   'speechiness': 0.0886,
#   'acousticness': 0.0209,
#   'instrumentalness': 0.0542,
#   'liveness': 0.0703,
#   'valence': 0.637,
#   'tempo': 124.927,
#   'type': 'audio_features',
#   'id': '20on25jryn53hWghthWWW3',
#   'uri': 'spotify:track:20on25jryn53hWghthWWW3',
#   'track_href': 'https://api.spotify.com/v1/tracks/20on25jryn53hWghthWWW3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20on25jryn53hWghthWWW3',
#   'duration_ms': 157890,
#   'time_signature': 4},
#  {'danceability': 0.83,
#   'energy': 0.6,
#   'key': 5,
#   'loudness': -6.706,
#   'mode': 0,
#   'speechiness': 0.0483,
#   'acousticness': 0.22,
#   'instrumentalness': 3.3e-06,
#   'liveness': 0.11,
#   'valence': 0.77,
#   'tempo': 86.514,
#   'type': 'audio_features',
#   'id': '4VIyBZioj5khxauaZJexks',
#   'uri': 'spotify:track:4VIyBZioj5khxauaZJexks',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VIyBZioj5khxauaZJexks',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VIyBZioj5khxauaZJexks',
#   'duration_ms': 159160,
#   'time_signature': 4},
#  {'danceability': 0.836,
#   'energy': 0.846,
#   'key': 0,
#   'loudness': -4.673,
#   'mode': 1,
#   'speechiness': 0.0392,
#   'acousticness': 0.0907,
#   'instrumentalness': 0.047,
#   'liveness': 0.057,
#   'valence': 0.942,
#   'tempo': 122.042,
#   'type': 'audio_features',
#   'id': '0xfMlIW8lS40qvpsUw1l0X',
#   'uri': 'spotify:track:0xfMlIW8lS40qvpsUw1l0X',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xfMlIW8lS40qvpsUw1l0X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xfMlIW8lS40qvpsUw1l0X',
#   'duration_ms': 169945,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.655,
#   'key': 6,
#   'loudness': -5.869,
#   'mode': 0,
#   'speechiness': 0.359,
#   'acousticness': 0.398,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.552,
#   'tempo': 169.566,
#   'type': 'audio_features',
#   'id': '1umWYzhtxWxlVvnvfWLbT4',
#   'uri': 'spotify:track:1umWYzhtxWxlVvnvfWLbT4',
#   'track_href': 'https://api.spotify.com/v1/tracks/1umWYzhtxWxlVvnvfWLbT4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1umWYzhtxWxlVvnvfWLbT4',
#   'duration_ms': 176078,
#   'time_signature': 4},
#  {'danceability': 0.79,
#   'energy': 0.744,
#   'key': 9,
#   'loudness': -7.033,
#   'mode': 0,
#   'speechiness': 0.0294,
#   'acousticness': 0.287,
#   'instrumentalness': 0.000934,
#   'liveness': 0.0909,
#   'valence': 0.798,
#   'tempo': 123.984,
#   'type': 'audio_features',
#   'id': '0eZmBWVC1HYayrP2fqQ7nu',
#   'uri': 'spotify:track:0eZmBWVC1HYayrP2fqQ7nu',
#   'track_href': 'https://api.spotify.com/v1/tracks/0eZmBWVC1HYayrP2fqQ7nu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eZmBWVC1HYayrP2fqQ7nu',
#   'duration_ms': 174348,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.836,
#   'key': 7,
#   'loudness': -6.724,
#   'mode': 1,
#   'speechiness': 0.21,
#   'acousticness': 0.117,
#   'instrumentalness': 0,
#   'liveness': 0.0791,
#   'valence': 0.628,
#   'tempo': 147.927,
#   'type': 'audio_features',
#   'id': '2FQRZLR31e3423Nmrgv0Pv',
#   'uri': 'spotify:track:2FQRZLR31e3423Nmrgv0Pv',
#   'track_href': 'https://api.spotify.com/v1/tracks/2FQRZLR31e3423Nmrgv0Pv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FQRZLR31e3423Nmrgv0Pv',
#   'duration_ms': 171723,
#   'time_signature': 4},
#  {'danceability': 0.789,
#   'energy': 0.435,
#   'key': 2,
#   'loudness': -9.506,
#   'mode': 0,
#   'speechiness': 0.149,
#   'acousticness': 0.691,
#   'instrumentalness': 0.0395,
#   'liveness': 0.107,
#   'valence': 0.166,
#   'tempo': 122.997,
#   'type': 'audio_features',
#   'id': '6ngjb2Je6gEjjVOOQpWSWG',
#   'uri': 'spotify:track:6ngjb2Je6gEjjVOOQpWSWG',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ngjb2Je6gEjjVOOQpWSWG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ngjb2Je6gEjjVOOQpWSWG',
#   'duration_ms': 196375,
#   'time_signature': 4},
#  {'danceability': 0.633,
#   'energy': 0.397,
#   'key': 9,
#   'loudness': -8.919,
#   'mode': 0,
#   'speechiness': 0.0493,
#   'acousticness': 0.252,
#   'instrumentalness': 1.8e-05,
#   'liveness': 0.0916,
#   'valence': 0.212,
#   'tempo': 96.968,
#   'type': 'audio_features',
#   'id': '2PDM9Byxz5crB2IXuh2Oal',
#   'uri': 'spotify:track:2PDM9Byxz5crB2IXuh2Oal',
#   'track_href': 'https://api.spotify.com/v1/tracks/2PDM9Byxz5crB2IXuh2Oal',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PDM9Byxz5crB2IXuh2Oal',
#   'duration_ms': 183500,
#   'time_signature': 4},
#  {'danceability': 0.915,
#   'energy': 0.72,
#   'key': 8,
#   'loudness': -3.126,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.025,
#   'instrumentalness': 1.42e-05,
#   'liveness': 0.0942,
#   'valence': 0.631,
#   'tempo': 126.986,
#   'type': 'audio_features',
#   'id': '63aj87TQG6F3RVO5nbG2VQ',
#   'uri': 'spotify:track:63aj87TQG6F3RVO5nbG2VQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/63aj87TQG6F3RVO5nbG2VQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63aj87TQG6F3RVO5nbG2VQ',
#   'duration_ms': 131067,
#   'time_signature': 4},
#  {'danceability': 0.776,
#   'energy': 0.511,
#   'key': 8,
#   'loudness': -7.218,
#   'mode': 0,
#   'speechiness': 0.244,
#   'acousticness': 0.544,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.835,
#   'tempo': 74.973,
#   'type': 'audio_features',
#   'id': '3wyLJfkbukEpP3oMp6Typx',
#   'uri': 'spotify:track:3wyLJfkbukEpP3oMp6Typx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wyLJfkbukEpP3oMp6Typx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wyLJfkbukEpP3oMp6Typx',
#   'duration_ms': 129600,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.798,
#   'key': 1,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.034,
#   'instrumentalness': 4.19e-05,
#   'liveness': 0.0952,
#   'valence': 0.942,
#   'tempo': 116.032,
#   'type': 'audio_features',
#   'id': '6zSpb8dQRaw0M1dK8PBwQz',
#   'uri': 'spotify:track:6zSpb8dQRaw0M1dK8PBwQz',
#   'track_href': 'https://api.spotify.com/v1/tracks/6zSpb8dQRaw0M1dK8PBwQz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zSpb8dQRaw0M1dK8PBwQz',
#   'duration_ms': 202735,
#   'time_signature': 4},
#  {'danceability': 0.823,
#   'energy': 0.446,
#   'key': 8,
#   'loudness': -7.556,
#   'mode': 0,
#   'speechiness': 0.246,
#   'acousticness': 0.216,
#   'instrumentalness': 0.000119,
#   'liveness': 0.119,
#   'valence': 0.495,
#   'tempo': 114.03,
#   'type': 'audio_features',
#   'id': '2xFMvrqk99biaLQavjufta',
#   'uri': 'spotify:track:2xFMvrqk99biaLQavjufta',
#   'track_href': 'https://api.spotify.com/v1/tracks/2xFMvrqk99biaLQavjufta',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2xFMvrqk99biaLQavjufta',
#   'duration_ms': 169501,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.54,
#   'key': 4,
#   'loudness': -5.692,
#   'mode': 1,
#   'speechiness': 0.0493,
#   'acousticness': 0.299,
#   'instrumentalness': 0,
#   'liveness': 0.367,
#   'valence': 0.415,
#   'tempo': 121.932,
#   'type': 'audio_features',
#   'id': '4fouWK6XVHhzl78KzQ1UjL',
#   'uri': 'spotify:track:4fouWK6XVHhzl78KzQ1UjL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fouWK6XVHhzl78KzQ1UjL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fouWK6XVHhzl78KzQ1UjL',
#   'duration_ms': 168602,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.846,
#   'key': 1,
#   'loudness': -4.51,
#   'mode': 0,
#   'speechiness': 0.22,
#   'acousticness': 0.00614,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.546,
#   'tempo': 87.981,
#   'type': 'audio_features',
#   'id': '0e8nrvls4Qqv5Rfa2UhqmO',
#   'uri': 'spotify:track:0e8nrvls4Qqv5Rfa2UhqmO',
#   'track_href': 'https://api.spotify.com/v1/tracks/0e8nrvls4Qqv5Rfa2UhqmO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0e8nrvls4Qqv5Rfa2UhqmO',
#   'duration_ms': 143901,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.763,
#   'key': 7,
#   'loudness': -4.627,
#   'mode': 0,
#   'speechiness': 0.0435,
#   'acousticness': 0.0301,
#   'instrumentalness': 2.23e-05,
#   'liveness': 0.0901,
#   'valence': 0.464,
#   'tempo': 117.953,
#   'type': 'audio_features',
#   'id': '18asYwWugKjjsihZ0YvRxO',
#   'uri': 'spotify:track:18asYwWugKjjsihZ0YvRxO',
#   'track_href': 'https://api.spotify.com/v1/tracks/18asYwWugKjjsihZ0YvRxO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18asYwWugKjjsihZ0YvRxO',
#   'duration_ms': 164819,
#   'time_signature': 4},
#  {'danceability': 0.716,
#   'energy': 0.622,
#   'key': 1,
#   'loudness': -5.228,
#   'mode': 1,
#   'speechiness': 0.0641,
#   'acousticness': 0.0121,
#   'instrumentalness': 0,
#   'liveness': 0.293,
#   'valence': 0.717,
#   'tempo': 80.993,
#   'type': 'audio_features',
#   'id': '1YRaS0rNK8y9E5NeTrKe03',
#   'uri': 'spotify:track:1YRaS0rNK8y9E5NeTrKe03',
#   'track_href': 'https://api.spotify.com/v1/tracks/1YRaS0rNK8y9E5NeTrKe03',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YRaS0rNK8y9E5NeTrKe03',
#   'duration_ms': 137702,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.681,
#   'key': 5,
#   'loudness': -7.114,
#   'mode': 0,
#   'speechiness': 0.0265,
#   'acousticness': 0.00214,
#   'instrumentalness': 0.000307,
#   'liveness': 0.0861,
#   'valence': 0.448,
#   'tempo': 123.028,
#   'type': 'audio_features',
#   'id': '6OufwUcCqo81guU2jAlDVP',
#   'uri': 'spotify:track:6OufwUcCqo81guU2jAlDVP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6OufwUcCqo81guU2jAlDVP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OufwUcCqo81guU2jAlDVP',
#   'duration_ms': 241970,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.378,
#   'key': 7,
#   'loudness': -7.158,
#   'mode': 1,
#   'speechiness': 0.0473,
#   'acousticness': 0.516,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.161,
#   'tempo': 144.962,
#   'type': 'audio_features',
#   'id': '2EBnvom1dTybtm75a3Xh1T',
#   'uri': 'spotify:track:2EBnvom1dTybtm75a3Xh1T',
#   'track_href': 'https://api.spotify.com/v1/tracks/2EBnvom1dTybtm75a3Xh1T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2EBnvom1dTybtm75a3Xh1T',
#   'duration_ms': 204315,
#   'time_signature': 4},
#  {'danceability': 0.787,
#   'energy': 0.833,
#   'key': 8,
#   'loudness': -4.403,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.018,
#   'instrumentalness': 0.00747,
#   'liveness': 0.0374,
#   'valence': 0.796,
#   'tempo': 123.97,
#   'type': 'audio_features',
#   'id': '6Dy1jexKYriXAVG6evyUTJ',
#   'uri': 'spotify:track:6Dy1jexKYriXAVG6evyUTJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Dy1jexKYriXAVG6evyUTJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Dy1jexKYriXAVG6evyUTJ',
#   'duration_ms': 162604,
#   'time_signature': 4},
#  {'danceability': 0.921,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -6.589,
#   'mode': 1,
#   'speechiness': 0.0681,
#   'acousticness': 0.00266,
#   'instrumentalness': 1.07e-05,
#   'liveness': 0.103,
#   'valence': 0.697,
#   'tempo': 125.009,
#   'type': 'audio_features',
#   'id': '4mIWLMi5SAeX6FhnlaOj1y',
#   'uri': 'spotify:track:4mIWLMi5SAeX6FhnlaOj1y',
#   'track_href': 'https://api.spotify.com/v1/tracks/4mIWLMi5SAeX6FhnlaOj1y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4mIWLMi5SAeX6FhnlaOj1y',
#   'duration_ms': 229880,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.849,
#   'key': 9,
#   'loudness': -3.794,
#   'mode': 0,
#   'speechiness': 0.186,
#   'acousticness': 0.00253,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.774,
#   'tempo': 175.908,
#   'type': 'audio_features',
#   'id': '4btFHqumCO31GksfuBLLv3',
#   'uri': 'spotify:track:4btFHqumCO31GksfuBLLv3',
#   'track_href': 'https://api.spotify.com/v1/tracks/4btFHqumCO31GksfuBLLv3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4btFHqumCO31GksfuBLLv3',
#   'duration_ms': 236907,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.753,
#   'key': 11,
#   'loudness': -4.988,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.0143,
#   'instrumentalness': 0.000143,
#   'liveness': 0.0919,
#   'valence': 0.855,
#   'tempo': 98.028,
#   'type': 'audio_features',
#   'id': '4bnutybG1itDcpyoQo2Uoc',
#   'uri': 'spotify:track:4bnutybG1itDcpyoQo2Uoc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4bnutybG1itDcpyoQo2Uoc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4bnutybG1itDcpyoQo2Uoc',
#   'duration_ms': 180640,
#   'time_signature': 4},
#  {'danceability': 0.539,
#   'energy': 0.708,
#   'key': 5,
#   'loudness': -6.189,
#   'mode': 1,
#   'speechiness': 0.0976,
#   'acousticness': 0.0129,
#   'instrumentalness': 0,
#   'liveness': 0.14,
#   'valence': 0.381,
#   'tempo': 123.039,
#   'type': 'audio_features',
#   'id': '0JpEMzTHbt2zBIXrntrXzG',
#   'uri': 'spotify:track:0JpEMzTHbt2zBIXrntrXzG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JpEMzTHbt2zBIXrntrXzG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JpEMzTHbt2zBIXrntrXzG',
#   'duration_ms': 186141,
#   'time_signature': 4},
#  {'danceability': 0.604,
#   'energy': 0.366,
#   'key': 5,
#   'loudness': -7.519,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.578,
#   'instrumentalness': 0,
#   'liveness': 0.133,
#   'valence': 0.13,
#   'tempo': 141.981,
#   'type': 'audio_features',
#   'id': '0gplL1WMoJ6iYaPgMCL0gX',
#   'uri': 'spotify:track:0gplL1WMoJ6iYaPgMCL0gX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0gplL1WMoJ6iYaPgMCL0gX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0gplL1WMoJ6iYaPgMCL0gX',
#   'duration_ms': 224695,
#   'time_signature': 4},
#  {'danceability': 0.588,
#   'energy': 0.701,
#   'key': 9,
#   'loudness': -6.39,
#   'mode': 1,
#   'speechiness': 0.0402,
#   'acousticness': 0.00813,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.443,
#   'tempo': 104.988,
#   'type': 'audio_features',
#   'id': '3FeVmId7tL5YN8B7R3imoM',
#   'uri': 'spotify:track:3FeVmId7tL5YN8B7R3imoM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3FeVmId7tL5YN8B7R3imoM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FeVmId7tL5YN8B7R3imoM',
#   'duration_ms': 228000,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.667,
#   'key': 11,
#   'loudness': -4.668,
#   'mode': 0,
#   'speechiness': 0.0339,
#   'acousticness': 0.00173,
#   'instrumentalness': 2.85e-05,
#   'liveness': 0.1,
#   'valence': 0.468,
#   'tempo': 115.982,
#   'type': 'audio_features',
#   'id': '4rPkN1FMzQyFNP9cLUGIIB',
#   'uri': 'spotify:track:4rPkN1FMzQyFNP9cLUGIIB',
#   'track_href': 'https://api.spotify.com/v1/tracks/4rPkN1FMzQyFNP9cLUGIIB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rPkN1FMzQyFNP9cLUGIIB',
#   'duration_ms': 258004,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'type': 'audio_features',
#   'id': '6CDzDgIUqeDY5g8ujExx2f',
#   'uri': 'spotify:track:6CDzDgIUqeDY5g8ujExx2f',
#   'track_href': 'https://api.spotify.com/v1/tracks/6CDzDgIUqeDY5g8ujExx2f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6CDzDgIUqeDY5g8ujExx2f',
#   'duration_ms': 238805,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.612,
#   'key': 8,
#   'loudness': -6.627,
#   'mode': 0,
#   'speechiness': 0.363,
#   'acousticness': 0.835,
#   'instrumentalness': 0,
#   'liveness': 0.461,
#   'valence': 0.687,
#   'tempo': 179.629,
#   'type': 'audio_features',
#   'id': '2gQPv5jvVPqU2a9HhMNO1v',
#   'uri': 'spotify:track:2gQPv5jvVPqU2a9HhMNO1v',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gQPv5jvVPqU2a9HhMNO1v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gQPv5jvVPqU2a9HhMNO1v',
#   'duration_ms': 168020,
#   'time_signature': 4},
#  {'danceability': 0.625,
#   'energy': 0.85,
#   'key': 3,
#   'loudness': -3.98,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.0235,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.392,
#   'tempo': 129.841,
#   'type': 'audio_features',
#   'id': '2YyIZVbxDKCWolKTcbdp6B',
#   'uri': 'spotify:track:2YyIZVbxDKCWolKTcbdp6B',
#   'track_href': 'https://api.spotify.com/v1/tracks/2YyIZVbxDKCWolKTcbdp6B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YyIZVbxDKCWolKTcbdp6B',
#   'duration_ms': 237093,
#   'time_signature': 4},
#  {'danceability': 0.622,
#   'energy': 0.756,
#   'key': 11,
#   'loudness': -6.402,
#   'mode': 0,
#   'speechiness': 0.0718,
#   'acousticness': 0.123,
#   'instrumentalness': 0,
#   'liveness': 0.242,
#   'valence': 0.407,
#   'tempo': 72.821,
#   'type': 'audio_features',
#   'id': '6Mqh9nRS9ksN38qaaa6ZR0',
#   'uri': 'spotify:track:6Mqh9nRS9ksN38qaaa6ZR0',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Mqh9nRS9ksN38qaaa6ZR0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Mqh9nRS9ksN38qaaa6ZR0',
#   'duration_ms': 164500,
#   'time_signature': 4},
#  {'danceability': 0.591,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.484,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.0383,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.478,
#   'tempo': 169.928,
#   'type': 'audio_features',
#   'id': '5HCyWlXZPP0y6Gqq8TgA20',
#   'uri': 'spotify:track:5HCyWlXZPP0y6Gqq8TgA20',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HCyWlXZPP0y6Gqq8TgA20',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HCyWlXZPP0y6Gqq8TgA20',
#   'duration_ms': 141806,
#   'time_signature': 4},
#  {'danceability': 0.726,
#   'energy': 0.577,
#   'key': 2,
#   'loudness': -8.332,
#   'mode': 0,
#   'speechiness': 0.171,
#   'acousticness': 0.169,
#   'instrumentalness': 6.23e-06,
#   'liveness': 0.296,
#   'valence': 0.406,
#   'tempo': 145.939,
#   'type': 'audio_features',
#   'id': '2zc3acsVhebCn3oYmBh51v',
#   'uri': 'spotify:track:2zc3acsVhebCn3oYmBh51v',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zc3acsVhebCn3oYmBh51v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zc3acsVhebCn3oYmBh51v',
#   'duration_ms': 184599,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.781,
#   'key': 1,
#   'loudness': -4.806,
#   'mode': 1,
#   'speechiness': 0.053,
#   'acousticness': 0.0361,
#   'instrumentalness': 0,
#   'liveness': 0.0755,
#   'valence': 0.688,
#   'tempo': 97.014,
#   'type': 'audio_features',
#   'id': '00Blm7zeNqgYLPtW6zg8cj',
#   'uri': 'spotify:track:00Blm7zeNqgYLPtW6zg8cj',
#   'track_href': 'https://api.spotify.com/v1/tracks/00Blm7zeNqgYLPtW6zg8cj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00Blm7zeNqgYLPtW6zg8cj',
#   'duration_ms': 193507,
#   'time_signature': 4},
#  {'danceability': 0.827,
#   'energy': 0.699,
#   'key': 4,
#   'loudness': -4.802,
#   'mode': 0,
#   'speechiness': 0.0415,
#   'acousticness': 0.285,
#   'instrumentalness': 0.00915,
#   'liveness': 0.3,
#   'valence': 0.806,
#   'tempo': 136.996,
#   'type': 'audio_features',
#   'id': '5F3sqL2deoeV2kr8Vn9H4V',
#   'uri': 'spotify:track:5F3sqL2deoeV2kr8Vn9H4V',
#   'track_href': 'https://api.spotify.com/v1/tracks/5F3sqL2deoeV2kr8Vn9H4V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5F3sqL2deoeV2kr8Vn9H4V',
#   'duration_ms': 136000,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.673,
#   'key': 11,
#   'loudness': -6.941,
#   'mode': 0,
#   'speechiness': 0.0444,
#   'acousticness': 0.148,
#   'instrumentalness': 5.29e-05,
#   'liveness': 0.304,
#   'valence': 0.494,
#   'tempo': 121.963,
#   'type': 'audio_features',
#   'id': '1SOClUWhOi8vHZYMz3GluK',
#   'uri': 'spotify:track:1SOClUWhOi8vHZYMz3GluK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SOClUWhOi8vHZYMz3GluK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SOClUWhOi8vHZYMz3GluK',
#   'duration_ms': 237720,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.506,
#   'key': 9,
#   'loudness': -6.919,
#   'mode': 1,
#   'speechiness': 0.128,
#   'acousticness': 0.0135,
#   'instrumentalness': 0.0937,
#   'liveness': 0.167,
#   'valence': 0.325,
#   'tempo': 145.041,
#   'type': 'audio_features',
#   'id': '6fuO9uk9wbjCHvQJqk2Qpx',
#   'uri': 'spotify:track:6fuO9uk9wbjCHvQJqk2Qpx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6fuO9uk9wbjCHvQJqk2Qpx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6fuO9uk9wbjCHvQJqk2Qpx',
#   'duration_ms': 105983,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.783,
#   'key': 11,
#   'loudness': -4.424,
#   'mode': 0,
#   'speechiness': 0.266,
#   'acousticness': 0.237,
#   'instrumentalness': 0,
#   'liveness': 0.434,
#   'valence': 0.555,
#   'tempo': 77.011,
#   'type': 'audio_features',
#   'id': '1r9xUipOqoNwggBpENDsvJ',
#   'uri': 'spotify:track:1r9xUipOqoNwggBpENDsvJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1r9xUipOqoNwggBpENDsvJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1r9xUipOqoNwggBpENDsvJ',
#   'duration_ms': 173381,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.741,
#   'key': 2,
#   'loudness': -5.569,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.185,
#   'instrumentalness': 2.91e-05,
#   'liveness': 0.415,
#   'valence': 0.441,
#   'tempo': 153.96,
#   'type': 'audio_features',
#   'id': '6I3mqTwhRpn34SLVafSH7G',
#   'uri': 'spotify:track:6I3mqTwhRpn34SLVafSH7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6I3mqTwhRpn34SLVafSH7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6I3mqTwhRpn34SLVafSH7G',
#   'duration_ms': 153190,
#   'time_signature': 4},
#  {'danceability': 0.831,
#   'energy': 0.554,
#   'key': 1,
#   'loudness': -9.998,
#   'mode': 0,
#   'speechiness': 0.218,
#   'acousticness': 0.161,
#   'instrumentalness': 6.12e-05,
#   'liveness': 0.152,
#   'valence': 0.396,
#   'tempo': 140.026,
#   'type': 'audio_features',
#   'id': '7hU3IHwjX150XLoTVmjD0q',
#   'uri': 'spotify:track:7hU3IHwjX150XLoTVmjD0q',
#   'track_href': 'https://api.spotify.com/v1/tracks/7hU3IHwjX150XLoTVmjD0q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hU3IHwjX150XLoTVmjD0q',
#   'duration_ms': 168228,
#   'time_signature': 4},
#  {'danceability': 0.839,
#   'energy': 0.506,
#   'key': 5,
#   'loudness': -6.714,
#   'mode': 0,
#   'speechiness': 0.133,
#   'acousticness': 0.00207,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.44,
#   'tempo': 154.12,
#   'type': 'audio_features',
#   'id': '4R67rQNSbbsR4TdUVOIdez',
#   'uri': 'spotify:track:4R67rQNSbbsR4TdUVOIdez',
#   'track_href': 'https://api.spotify.com/v1/tracks/4R67rQNSbbsR4TdUVOIdez',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4R67rQNSbbsR4TdUVOIdez',
#   'duration_ms': 149610,
#   'time_signature': 4}]
